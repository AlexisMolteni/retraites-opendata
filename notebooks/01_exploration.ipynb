# %% [markdown]
# # 01 — Exploration & Qualité des données
#
# Découverte des datasets disponibles via l'API OpenDataSoft d'Assurance Retraite.

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
from src.fetch_data import list_datasets, fetch_dataset

# %% [markdown]
# ## 1. Lister les datasets disponibles

# %%
datasets = list_datasets()
catalog = pd.DataFrame([{
    'id': d['dataset_id'],
    'titre': d.get('metas', {}).get('default', {}).get('title', ''),
    'enregistrements': d.get('metas', {}).get('default', {}).get('records_count', '')
} for d in datasets])
catalog
# Out:
#                                                    id  \
# 0          attribution-de-lannee-par-region-debitrice
# 1   montant-mensuel-moyen-de-la-pension-de-base-at...
# 2   age-a-lattribution-pour-lensemble-des-droits-d...
# 3   1-montant-mensuel-moyen-de-la-pension-de-base-...
# 4   durees-moyennes-dassurance-limitees-et-non-lim...
# 5   montant-global-de-la-retraite-au-31-decembre-p...
# 6   repartition-par-age-a-lattribution-pour-lensem...
# 7   montant-global-de-la-retraite-attribuee-selon-...
# 8                      age-moyen-au-31-decembre-copie
# 9       nombre-de-retraites-par-carsat-au-31-decembre
# 10  nombre-de-retraites-au-31-decembre-selon-la-na...
# 11                           age-moyen-a-lattribution
# 12  repartition-par-age-a-lattribution-des-droits-...
# 13      montant-mensuel-moyen-de-la-retraite-globale-
# 14  montant-global-de-la-retraite-attribuee-par-ty...
# 15     attributions-de-lannee-selon-le-type-de-droits
# 16  salaires-annuels-moyen-de-base-des-pensions-at...
# 17       nombre-de-retraites-au-31-decembre-par-genre
# 18       montant-global-de-la-retraite-au-31-decembre
#
#                                                 titre  enregistrements
# 0         Attribution de l'année par région débitrice             1119
# 1   Montant de base de la retraite attribuée par c...              756
# 2   Répartition par âge à l'attribution pour l'ens...             2478
# 3   Montant de base de la retraite de droit direct...              189
# 4   Durées d'assurance limitées et non limitées de...              118
# 5   Montant global  de la retraite au 31 décembre ...              116
# 6   Répartition par âge à l'attribution pour l'ens...             2518
# 7   Montant global de la retraite attribuée selon ...              123
# 8                            Âge moyen au 31 décembre               52
# 9       Nombre de retraités par Carsat au 31 décembre               66
# 10  Nombre de retraités au 31 décembre selon la na...               66
# 11                          Âge moyen à l'attribution               63
# 12  Répartition par âge à l'attribution des droits...             2499
# 13  Montant mensuel moyen de la retraite globale (...               96
# 14  Montant global de la retraite attribuée par ty...              378
# 15    Attributions de l'année selon le type de droits              126
# 16  Revenu annuel moyen des retraites attribuées d...              187
# 17  Nombre de retraités au 31 décembre selon le genre              104
# 18       Montant global de la retraite au 31 décembre               66

# %% [markdown]
# ## 2. Aperçu d'un dataset

# %%
# Remplacer par l'ID souhaité
DATASET_ID = catalog['id'].iloc[0]
df = fetch_dataset(DATASET_ID)
print(f"Shape : {df.shape}")
df.head()
# Out:
# Shape : (1119, 3)
#   annees   carsat  effectif
# 0   1964  Limoges      8514
# 1   1965    Dijon     11855
# 2   1965    Paris     79680
# 3   1965   Rennes      7796
# 4   1966   Nantes      8697

# %% [markdown]
# ## 3. Qualité — valeurs manquantes

# %%
missing = df.isnull().sum().sort_values(ascending=False)
missing[missing > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ## 4. Types de données

# %%
df.dtypes
# Out:
# annees      object
# carsat      object
# effectif     int64
# dtype: object
